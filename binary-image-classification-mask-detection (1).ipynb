# %% [markdown]
# # Image Classification to Detect whether a Person is Wearing a Mask
# #### ~Arnav Modi
#
# The following program is created to look at images and tell whether the person in the image is wearing a mask or not. The model was able to detect whether a person is wearing a mask with an accuracy of 98% on the testing dataset. The dataset for this binary classification problem was taken from kaggle. This is the link for the dataset: [Face Mask ~ 12k Images Dataset](https://www.kaggle.com/ashishjangra27/face-mask-12k-images-dataset). This model can be used in workplaces to check whether a person is wearing a mask, thus allowing a person to enter a building only if he/she is wearing a mask. The following are the components of this program:
#
# * Importing libraries
# * Loading the dataset from the kaggle directory
# * Splitting the training data into separate numpy arrays of images and their labels
# * Splitting the testing data into separate numpy arrays of images and their labels
# * Defining the model
# * Compiling the model
# * Fitting the model
# * Visualising the accuracy and loss during the training
# * Evaluating the model on the testing dataset
# * Visualising predictions made on some images from the validation dataset

# %% [markdown]
# ## Importing all the required libraries

# %%
import numpy as np
import pandas as pd
import cv2    
from keras.utils import plot_model
from keras.utils.vis_utils import model_to_dot
from tqdm import tqdm
from PIL import Image
from keras.layers import Convolution2D, Activation,MaxPooling2D, Flatten, Dense, BatchNormalization, Input, ZeroPadding2D
from keras.models import Model
from IPython.display import SVG
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.applications.imagenet_utils import preprocess_input
import random


print("All the libraries have been imported...")
# Out:
# All the libraries have been imported...

# %% [markdown]
# # Loading the Dataset of 12,000 images
#
# The output for the below cell has not been shown fully as it would take up 12,000 lines. Only the path of every 100th image has been shown. So, in reality, 100 times the images whose directories are shown have been loaded.

# %%
import os
num = 1
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if num % 100 == 0 and "Validation" not in dirname:
            print(os.path.join(dirname, filename))
        else:
            os.path.join(dirname, filename)
        num += 1
# Out:
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithoutMask/2904.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithoutMask/4796.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithoutMask/1217.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithoutMask/4780.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithoutMask/4597.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask/Augmented_787_5812521.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask/Augmented_125_3402457.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask/Augmented_191_53771.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask/Augmented_282_1324197.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5590.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5197.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4761.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3715.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2233.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3838.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2429.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/629.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4316.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/197.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2593.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5554.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2644.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5874.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1826.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/724.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1390.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2944.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3611.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1083.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1115.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3750.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2587.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2177.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4951.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4823.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5425.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4161.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/873.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5787.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3930.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5903.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2201.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/836.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1318.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1856.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2421.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5833.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2262.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3786.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3958.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/826.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5056.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/475.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1031.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2808.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4732.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/694.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4050.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3233.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_79_948721.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_739_5721031.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_382_384790.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_442_4171845.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_395_7340551.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_419_4891395.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_522_2736971.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_862_1621475.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_889_6040153.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_428_7182948.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_819_5117461.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/1538.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_878_2737151.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_523_8397853.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_687_2666298.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_409_329338.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_756_4018861.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_198_2963185.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_521_9116113.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_231_6911641.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_797_5606961.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_232_4039964.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_396_3876777.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/66.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_522_3808835.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_230_6204206.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_63_1467301.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_644_448466.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_770_8710479.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_186_9509976.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_304_5073210.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_377_1095603.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_470_6549642.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/1173.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/298.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_850_5291320.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_363_9045348.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_114_2543932.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/760.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_809_2142218.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_101_769518.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_590_8848533.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_821_3694593.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_300_469726.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_364_1490404.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_854_3459820.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_878_7606366.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/590.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_761_675988.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/Augmented_536_1587749.png

# %% [markdown]
# # Splitting the training data into x_train and y_train
#
# The training data is the dataset on which the mask detection model would be trained. In the dataset used, there are 10,000 training examples. Both x_train and y_train are numpy arrays. By convention, in machine learning, x_train contains the training data and y_train contains the corresponding labels for that training data. In this program, x_train contains the images and y_train contains the labels for for those images (ie. with or without mask).

# %%
print("Loading the images in the training dataset...")
train_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/'
x_train = []
y_train = []
lst_show = []

for folder in os.listdir(train_dir):
    
    if folder == "WithoutMask":
        val = 0
    else:
        val = 1
    
    for file_name in tqdm(os.listdir(os.path.join(train_dir, folder))):
        
        folder_path = os.path.join(train_dir, folder)
        
        image_path = os.path.join(folder_path, file_name)
        
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, (64, 64))
        final_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
        
        x_train.append(final_image)
        y_train.append(val)
        
x_train = np.array(x_train, dtype = "float32")
y_train = np.array(y_train, dtype = "int32")
# Out:
#   0%|          | 8/5000 [00:00<01:03, 79.11it/s]
# Loading the images in the training dataset...
# 100%|██████████| 5000/5000 [00:38<00:00, 128.78it/s]
# 100%|██████████| 5000/5000 [00:43<00:00, 114.22it/s]

# %% [markdown]
# # Checking if the training data has been loaded properly into x_train and y_train

# %%
x_train_shape = x_train.shape

print("Number of images in the training dataset =", x_train_shape[0])
print("Size of images in the training dataset = ", x_train_shape[1], "x", x_train_shape[2])
print("Number of channels in the image =", x_train_shape[3], "(RGB image)")
print()
y_train_shape = y_train.shape
print("Number of labels corresponding to the images =", y_train_shape[0])
# Out:
# Number of images in the training dataset = 10000
# Size of images in the training dataset =  64 x 64
# Number of channels in the image = 3 (RGB image)
#
# Number of labels corresponding to the images = 10000

# %% [markdown]
# # Splitting the testing data into x_test and y_test
#
# The testing data is the dataset on which the accuracy of the mask detection model would be evaluated. In the dataset used, there are roughly 1,000 testing examples. Both x_test and y_test are numpy arrays. By convention, in machine learning, x_test contains the testing data and y_test contains the corresponding labels for that testing data. In this program, x_test contains the images and y_test contains the labels for for images (ie. with or without mask).

# %%
print("Loading the images in the test dataset...")
test_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/'
x_test = []
y_test = []

for folder in os.listdir(test_dir):
    
    if folder == "WithoutMask":
        val = 0
    else:
        val = 1
    
    for file_name in tqdm(os.listdir(os.path.join(test_dir, folder))):
        
        folder_path = os.path.join(test_dir, folder)
        
        image_path = os.path.join(folder_path, file_name)
        
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, (64, 64))
        final_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
            
        x_test.append(final_image)
        y_test.append(val)
        
x_test = np.array(x_test, dtype = "float32")
y_test = np.array(y_test, dtype = "int32")
# Out:
#   3%|▎         | 13/509 [00:00<00:03, 125.53it/s]
# Loading the images in the test dataset...
# 100%|██████████| 509/509 [00:03<00:00, 130.08it/s]
# 100%|██████████| 483/483 [00:04<00:00, 114.18it/s]

# %% [markdown]
# # Checking if the training data has been loaded properly into x_test and y_test

# %%
x_test_shape = x_test.shape

print("Number of images in the testing dataset =", x_test_shape[0])
print("Size of images in the testing dataset = ", x_train_shape[1], "x", x_test_shape[2])
print("Number of channels in the image =", x_test_shape[3], "(RGB image)")
print()

y_test_shape = y_test.shape

print("Number of labels corresponding to the images =", y_test_shape[0])
# Out:
# Number of images in the testing dataset = 992
# Size of images in the testing dataset =  64 x 64
# Number of channels in the image = 3 (RGB image)
#
# Number of labels corresponding to the images = 992

# %% [markdown]
# # This function has been defined to create the model on which the dataset will be trained
#
# ## Steps which have been followed to create the convolutional neural network:
# * Padding
# * Convolution
# * Batch Normalization
# * relu Activation
# * MaxPooling
# * Flatten
# * Dense
# * Model
#
# ### Padding the Image
# The main reason behind the padding of an image is to ensure that the features of the pixels which are present at the boundary of the image do not get disregarded when convolution is performed in the next step.
#
#
# ### Performing one round of convolution
# A convolutional filter is applied over the image. Generally, as in this program, convolution shrinks the size of the image and increases the number of channels. The filter passes over the image according to the specified stride (jump value) and in the end produces a weighted sum over each of its positions on the main image.
#
# ### Applying Batch Normalization
# Batch normalisation allows networks to the trained very quickly.
#
#
# ### Applying the relu non-linearity
# The main role of the relu activation is to detect features from the filtered image produced as a result of applying convolution.
#
# ### Applying MaxPooling
# Maxpooling is used in order to condense the image so that the features which were detected by applying the activation function can be enhanced.
#
# ### Applying Flatten
# The main reason for its use is to convert the 3-dimensional array into a 1-dimensional vector without losing important features which whre detected by the relu activation.
#
# ### Applying Dense
# Dense is used to create the final fully connected layer.
#
# ### Model
# Combines the layers above to create a model. This model is used later on to view the summary of the model, train the data, and to evaluate the accuracy of the testing data.

# %%
def FaceMaskModel(shape):
    
    X_input = Input(shape)
    
    padding_dimensions = (2, 2)
    X = ZeroPadding2D(padding_dimensions)(X_input)
    
    layers = 32
    filter_size = (8, 8)
    strides = (1, 1)
    
    X = Convolution2D(layers, filter_size, strides = strides, name = "Convolution")(X)
    X = BatchNormalization(axis = 1, name = "Batch_Normalization")(X)
    X = Activation("relu")(X)
    
    X = MaxPooling2D((3, 3), name = "Max_pooling")(X)
    
    X = Flatten()(X)
    X = Dense(1, activation = "sigmoid", name = "fully_connected_layer")(X)
    
    face_mask_model = Model(inputs = X_input, outputs = X, name = "Face_Mask_Classifier")
    
    return face_mask_model

# %% [markdown]
# # The function FaceMaskModel (which is defined above) has been called on the training images

# %%
face_mask_model = FaceMaskModel(x_train.shape[1:])

# %% [markdown]
# # Summary of the FaceMaskModel

# %%
face_mask_model.summary()
# Out:
# Model: "Face_Mask_Classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 68, 68, 3)         0
# _________________________________________________________________
# Convolution (Conv2D)         (None, 61, 61, 32)        6176
# _________________________________________________________________
# Batch_Normalization (BatchNo (None, 61, 61, 32)        244
# _________________________________________________________________
# activation (Activation)      (None, 61, 61, 32)        0
# _________________________________________________________________
# Max_pooling (MaxPooling2D)   (None, 20, 20, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# fully_connected_layer (Dense (None, 1)                 12801
# =================================================================
# Total params: 19,221
# Trainable params: 19,099
# Non-trainable params: 122
# _________________________________________________________________

# %%
plot_model(face_mask_model, to_file='illustration.png')
SVG(model_to_dot(face_mask_model).create(prog='dot', format='svg'))

# %% [markdown]
# # Compiling the model
#
# The adam optimizer is used with a loss function called binary crossentropy as this is a binary classification problem (ie. we only have to classifiy images as with mask and without mask). Various metrics can be used whose values will be displayed while the data is being trained. Here only the accuracy metric has been used

# %%
face_mask_model.compile(optimizer = "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %% [markdown]
# # The function "fit" is  used to train the data on the FaceMaskModel

# %%
history = face_mask_model.fit(x = x_train,y = y_train, epochs = 32 ,batch_size = 10)
# Out:
# Epoch 1/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.1666 - accuracy: 0.9363
# Epoch 2/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0847 - accuracy: 0.9720
# Epoch 3/32
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.0481 - accuracy: 0.9828
# Epoch 4/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0495 - accuracy: 0.9829
# Epoch 5/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0419 - accuracy: 0.9843
# Epoch 6/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0326 - accuracy: 0.9881
# Epoch 7/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0332 - accuracy: 0.9881
# Epoch 8/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0285 - accuracy: 0.9894
# Epoch 9/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0251 - accuracy: 0.9894
# Epoch 10/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0272 - accuracy: 0.9904
# Epoch 11/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0212 - accuracy: 0.9918
# Epoch 12/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0179 - accuracy: 0.9927
# Epoch 13/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0213 - accuracy: 0.9929
# Epoch 14/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0175 - accuracy: 0.9936
# Epoch 15/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0149 - accuracy: 0.9945
# Epoch 16/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0147 - accuracy: 0.9946
# Epoch 17/32
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0099 - accuracy: 0.99640s - loss: 0.0099 - accuracy
# Epoch 18/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0207 - accuracy: 0.9926
# Epoch 19/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9949
# Epoch 20/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0096 - accuracy: 0.9961
# Epoch 21/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9953
# Epoch 22/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0187 - accuracy: 0.9927
# Epoch 23/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0088 - accuracy: 0.9968
# Epoch 24/32
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.0109 - accuracy: 0.9963
# Epoch 25/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0084 - accuracy: 0.9967
# Epoch 26/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0101 - accuracy: 0.9969
# Epoch 27/32
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0107 - accuracy: 0.9958
# Epoch 28/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0061 - accuracy: 0.9978
# Epoch 29/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0062 - accuracy: 0.9982
# Epoch 30/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0088 - accuracy: 0.9963
# Epoch 31/32
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 32/32
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0066 - accuracy: 0.9972

# %% [markdown]
# # Visualising the loss during training at the end of each successive epoch

# %%
import matplotlib.pyplot as plt

print("As a general trend, the loss should decrease with successive epochs...")

epochs = [i for i in range(1, 33)]

loss = [history.history['loss']]

plt.plot(epochs, loss[0], color = "red",linewidth = 3)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.title("epochs vs loss (Training Data)")

plt.show()
# Out:
# As a general trend, the loss should decrease with successive epochs...

# %% [markdown]
# # Visualising the accuracy during training at the end of each successive epoch

# %%
print("As a general trend, the accuracy should increase with successive epochs...")

epochs = [i for i in range(1, 33)]

accuracy = [history.history['accuracy']]

plt.plot(epochs, accuracy[0], color = "green",linewidth = 3)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.title("epochs vs accuracy (Training Data)")
plt.show()
# Out:
# As a general trend, the accuracy should increase with successive epochs...

# %% [markdown]
# # Testing the accuracy of the model on the test dataset.
# This will indicate the true accuracy of the model. This is because the model is now making predictions for a dataset of images it has not been trained on (ie. the model has not come across these images previously)

# %%
loss, acc = face_mask_model.evaluate(x = x_test,y = y_test)
print()
print ("Loss =" , round(loss, 3))
print ("Test Accuracy =" , round(acc*100, 3), "%")
# Out:
# 31/31 [==============================] - 1s 40ms/step - loss: 0.0380 - accuracy: 0.9849
#
# Loss = 0.038
# Test Accuracy = 98.488 %

# %% [markdown]
# # Visualising predictions made on some images from the validation dataset

# %%
dictionary = {0: "Without Mask", 1: "With Mask"}

validation_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/'
validation_image_paths = []

for folder in os.listdir(validation_dir):
    
    if folder == "WithoutMask":
        val = 0
    else:
        val = 1
    
    for file_name in tqdm(os.listdir(os.path.join(validation_dir, folder))):
        
        folder_path = os.path.join(validation_dir, folder)
        
        image_path = os.path.join(folder_path, file_name)
        
        validation_image_paths.append(image_path)


validation_image_paths_20random = random.choices(validation_image_paths,k = 20)

        
def multiple_img_show(path):
    img = tf.keras.preprocessing.image.load_img(path, target_size = (64, 64))
    x = tf.keras.preprocessing.image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    prediction = int(face_mask_model.predict(x)[0])
    plt.xlabel(dictionary[prediction], color = "blue")
    plt.imshow(img)
    plt.figure()


for path in validation_image_paths_20random:
    multiple_img_show(path)
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 135104.01it/s]
# 100%|██████████| 400/400 [00:00<00:00, 142505.87it/s]

# %% [markdown]
# # THE END...
